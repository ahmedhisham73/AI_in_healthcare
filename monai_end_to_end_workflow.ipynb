# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedhisham73/AI_in_healthcare/blob/main/monai_end_to_end_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU "monai[ignite, nibabel, torchvision, tqdm]==0.6.0"
# Out:
#      |████████████████████████████████| 584 kB 4.1 MB/s
#      |████████████████████████████████| 221 kB 74.0 MB/s

# %%
# !nvidia-smi
# Out:
# Thu Dec  9 13:28:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import shutil
import tempfile

import matplotlib.pyplot as plt
import numpy as np
import PIL

import torch
import monai

from monai.apps import download_and_extract
from monai.config import print_config
from monai.metrics import ROCAUCMetric
from monai.data import decollate_batch, partition_dataset_classes
from monai.networks.nets import DenseNet121
from monai.transforms import (
    AddChannel,
    Compose,
    LoadImage,
    RandFlip,
    RandRotate,
    RandZoom,
    ScaleIntensity,
    ToTensor,
    Activations,
    AsDiscrete,
    EnsureType
)
from monai.utils import set_determinism

# %%
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmp_hkm7vxo

# %%
resource = "https://www.dropbox.com/s/5wwskxctvcxiuea/MedNIST.tar.gz?dl=1"
md5 = "0bc7306e7427e00ad1c5526a6677552d"

compressed_file = os.path.join(root_dir, "MedNIST.tar.gz")
data_dir = os.path.join(root_dir, "MedNIST")
if not os.path.exists(data_dir):
    download_and_extract(resource, compressed_file, root_dir, md5)
# Out:
# MedNIST.tar.gz: 59.0MB [00:06, 9.65MB/s]
# Downloaded: /tmp/tmp_hkm7vxo/MedNIST.tar.gz
# Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.
# Writing into directory: /tmp/tmp_hkm7vxo.

# %%
set_determinism(seed=0)

# %%
class_names = sorted(x for x in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, x)))
num_class = len(class_names)

image_files = [
    [
        os.path.join(data_dir, class_names[i], x)
        for x in os.listdir(os.path.join(data_dir, class_names[i]))
    ]
    for i in range(num_class)
]

num_each = [len(image_files[i]) for i in range(num_class)]
image_files_list = []
image_class = []

for i in range(num_class):
    image_files_list.extend(image_files[i])
    image_class.extend([i] * num_each[i])
    
num_total = len(image_class)
image_width, image_height = PIL.Image.open(image_files_list[0]).size

print(f"Total image count: {num_total}")
print(f"Image dimensions: {image_width} x {image_height}")
print(f"Label names: {class_names}")
print(f"Label counts: {num_each}")
# Out:
# Total image count: 58954
# Image dimensions: 64 x 64
# Label names: ['AbdomenCT', 'BreastMRI', 'CXR', 'ChestCT', 'Hand', 'HeadCT']
# Label counts: [10000, 8954, 10000, 10000, 10000, 10000]

# %%
plt.subplots(3, 3, figsize=(8, 8))
for i, k in enumerate(np.random.randint(num_total, size=9)):
    im = PIL.Image.open(image_files_list[k])
    arr = np.array(im)
    plt.subplot(3, 3, i + 1)
    plt.xlabel(class_names[image_class[k]])
    plt.imshow(arr, cmap="gray", vmin=0, vmax=255)
plt.tight_layout()
plt.show()

# %%
train_inds, val_inds, test_inds = partition_dataset_classes(np.arange(len(image_files_list)), 
                                                            image_class,(80, 10, 10), shuffle=True)

train_x = [image_files_list[i] for i in train_inds]
train_y = [image_class[i] for i in train_inds]
val_x = [image_files_list[i] for i in val_inds]
val_y = [image_class[i] for i in val_inds]
test_x = [image_files_list[i] for i in test_inds]
test_y = [image_class[i] for i in test_inds]

print(f"Training count: {len(train_x)}, Validation count: {len(val_x)}, Test count: {len(test_x)}")
# Out:
# Training count: 47163, Validation count: 5895, Test count: 5895

# %%
train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True),
        RandFlip(spatial_axis=0, prob=0.5),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

act = Compose([EnsureType(), Activations(softmax=True)])
to_onehot = Compose([EnsureType(), AsDiscrete(to_onehot=True, n_classes=num_class)])

# %%
batch_size = 512
num_workers = 10

class MedNISTDataset(torch.utils.data.Dataset):
    def __init__(self, image_files, labels, transforms):
        self.image_files = image_files
        self.labels = labels
        self.transforms = transforms

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, index):
        return self.transforms(self.image_files[index]), self.labels[index]


train_ds = MedNISTDataset(train_x, train_y, train_transforms)
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers)

val_ds = MedNISTDataset(val_x, val_y, val_transforms)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=batch_size, num_workers=num_workers)

test_ds = MedNISTDataset(test_x, test_y, val_transforms)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, num_workers=num_workers)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
learning_rate = 1e-5
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = DenseNet121(spatial_dims=2, in_channels=1, out_channels=num_class).to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), learning_rate)

# %%
epoch_num = 4
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()
auc_metric = ROCAUCMetric()

for epoch in range(epoch_num):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epoch_num}")

    epoch_loss = 0
    step = 1

    steps_per_epoch = len(train_ds) // train_loader.batch_size

    # put the network in train mode; this tells the network and its modules to
    # enable training elements such as normalisation and dropout, where applicable
    net.train()
    for batch_data in train_loader:

        # move the data to the GPU
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device)

        # prepare the gradients for this step's back propagation
        optimizer.zero_grad()
        
        # run the network forwards
        outputs = net(inputs)
        
        # run the loss function on the outputs
        loss = loss_function(outputs, labels)
        
        # compute the gradients
        loss.backward()
        
        # tell the optimizer to update the weights according to the gradients
        # and its internal optimisation strategy
        optimizer.step()

        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size + 1}, training_loss: {loss.item():.4f}")
        step += 1

    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    # after each epoch, run our metrics to evaluate it, and, if they are an improvement,
    # save the model out
    
    # switch off training features of the network for this pass
    net.eval()

    # 'with torch.no_grad()' switches off gradient calculation for the scope of its context
    with torch.no_grad():
        # create lists to which we will concatenate the the validation results
        preds = list()
        labels = list()

        # iterate over each batch of images and run them through the network in evaluation mode
        for val_data in val_loader:
            val_images, val_labels = val_data[0].to(device), val_data[1].to(device)

            # run the network
            val_pred = net(val_images)

            preds.append(val_pred)
            labels.append(val_labels)

        # concatenate the predicted labels with each other and the actual labels with each other
        y_pred = torch.cat(preds)
        y = torch.cat(labels)

        # we are using the area under the receiver operating characteristic (ROC) curve to determine
        # whether this epoch has improved the best performance of the network so far, in which case
        # we save the network in this state
        y_onehot = [to_onehot(i) for i in decollate_batch(y)]        
        y_pred_act = [act(i) for i in decollate_batch(y_pred)]
        
        auc_metric(y_pred_act, y_onehot)
        auc_value = auc_metric.aggregate()
        auc_metric.reset()
        metric_values.append(auc_value)
        
        acc_value = torch.eq(y_pred.argmax(dim=1), y)
        acc_metric = acc_value.sum().item() / len(acc_value)
        
        if auc_value > best_metric:
            best_metric = auc_value
            best_metric_epoch = epoch + 1
            torch.save(net.state_dict(), os.path.join(root_dir, "best_metric_model.pth"))
            print("saved new best metric network")
            
        print(
            f"current epoch: {epoch + 1} current AUC: {auc_value:.4f} /"
            f" current accuracy: {acc_metric:.4f} best AUC: {best_metric:.4f} /"
            f" at epoch: {best_metric_epoch}"
        )

print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
# Out:
# ----------
# epoch 1/4
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 1/93, training_loss: 1.7700
# 2/93, training_loss: 1.7658
# 3/93, training_loss: 1.7299
# 4/93, training_loss: 1.7177
# 5/93, training_loss: 1.6830
# 6/93, training_loss: 1.6622
# 7/93, training_loss: 1.6531
# 8/93, training_loss: 1.6289
# 9/93, training_loss: 1.6108
# 10/93, training_loss: 1.5784
# 11/93, training_loss: 1.5607
# 12/93, training_loss: 1.5430
# 13/93, training_loss: 1.5254
# 14/93, training_loss: 1.4918
# 15/93, training_loss: 1.4724
# 16/93, training_loss: 1.4550
# 17/93, training_loss: 1.4315
# 18/93, training_loss: 1.4205
# 19/93, training_loss: 1.3929
# 20/93, training_loss: 1.3746
# 21/93, training_loss: 1.3692
# 22/93, training_loss: 1.3522
# 23/93, training_loss: 1.3465
# 24/93, training_loss: 1.3156
# 25/93, training_loss: 1.2797
# 26/93, training_loss: 1.2762
# 27/93, training_loss: 1.2673
# 28/93, training_loss: 1.2269
# 29/93, training_loss: 1.2150
# 30/93, training_loss: 1.2011
# 31/93, training_loss: 1.2118
# 32/93, training_loss: 1.1698
# 33/93, training_loss: 1.1916
# 34/93, training_loss: 1.1453
# 35/93, training_loss: 1.1521
# 36/93, training_loss: 1.1248
# 37/93, training_loss: 1.1130
# 38/93, training_loss: 1.0940
# 39/93, training_loss: 1.1057
# 40/93, training_loss: 1.0771
# 41/93, training_loss: 1.0476
# 42/93, training_loss: 1.0597
# 43/93, training_loss: 1.0390
# 44/93, training_loss: 1.0086
# 45/93, training_loss: 1.0167
# 46/93, training_loss: 0.9951
# 47/93, training_loss: 1.0058
# 48/93, training_loss: 0.9742
# 49/93, training_loss: 0.9468
# 50/93, training_loss: 0.9201
# 51/93, training_loss: 0.9721
# 52/93, training_loss: 0.9245
# 53/93, training_loss: 0.9109
# 54/93, training_loss: 0.9084
# 55/93, training_loss: 0.9307
# 56/93, training_loss: 0.8638
# 57/93, training_loss: 0.8834
# 58/93, training_loss: 0.8540
# 59/93, training_loss: 0.8379
# 60/93, training_loss: 0.8603
# 61/93, training_loss: 0.8454
# 62/93, training_loss: 0.8638
# 63/93, training_loss: 0.8145
# 64/93, training_loss: 0.8035
# 65/93, training_loss: 0.7632
# 66/93, training_loss: 0.7784
# 67/93, training_loss: 0.7800
# 68/93, training_loss: 0.7460
# 69/93, training_loss: 0.7120
# 70/93, training_loss: 0.7922
# 71/93, training_loss: 0.7439
# 72/93, training_loss: 0.7365
# 73/93, training_loss: 0.7088
# 74/93, training_loss: 0.7133
# 75/93, training_loss: 0.7068
# 76/93, training_loss: 0.6982
# 77/93, training_loss: 0.7093
# 78/93, training_loss: 0.6708
# 79/93, training_loss: 0.6965
# 80/93, training_loss: 0.6268
# 81/93, training_loss: 0.6590
# 82/93, training_loss: 0.6924
# 83/93, training_loss: 0.6500
# 84/93, training_loss: 0.6672
# 85/93, training_loss: 0.6308
# 86/93, training_loss: 0.5827
# 87/93, training_loss: 0.6292
# 88/93, training_loss: 0.6184
# 89/93, training_loss: 0.6047
# 90/93, training_loss: 0.6015
# 91/93, training_loss: 0.5794
# 92/93, training_loss: 0.5928
# 93/93, training_loss: 0.6580
# epoch 1 average loss: 1.0398
# saved new best metric network
# current epoch: 1 current AUC: 0.9927 / current accuracy: 0.9369 best AUC: 0.9927 / at epoch: 1
# ----------
# epoch 2/4
# 1/93, training_loss: 0.5376
# 2/93, training_loss: 0.5682
# 3/93, training_loss: 0.5769
# 4/93, training_loss: 0.5379
# 5/93, training_loss: 0.5173
# 6/93, training_loss: 0.5605
# 7/93, training_loss: 0.5349
# 8/93, training_loss: 0.5336
# 9/93, training_loss: 0.4966
# 10/93, training_loss: 0.5368
# 11/93, training_loss: 0.5259
# 12/93, training_loss: 0.5171
# 13/93, training_loss: 0.5337
# 14/93, training_loss: 0.5204
# 15/93, training_loss: 0.4674
# 16/93, training_loss: 0.4743
# 17/93, training_loss: 0.4767
# 18/93, training_loss: 0.4882
# 19/93, training_loss: 0.4629
# 20/93, training_loss: 0.4266
# 21/93, training_loss: 0.4602
# 22/93, training_loss: 0.4451
# 23/93, training_loss: 0.4129
# 24/93, training_loss: 0.4408
# 25/93, training_loss: 0.4245
# 26/93, training_loss: 0.4482
# 27/93, training_loss: 0.3963
# 28/93, training_loss: 0.4264
# 29/93, training_loss: 0.4302
# 30/93, training_loss: 0.3968
# 31/93, training_loss: 0.4171
# 32/93, training_loss: 0.3902
# 33/93, training_loss: 0.3955
# 34/93, training_loss: 0.3930
# 35/93, training_loss: 0.3946
# 36/93, training_loss: 0.3970
# 37/93, training_loss: 0.3867
# 38/93, training_loss: 0.3440
# 39/93, training_loss: 0.3554
# 40/93, training_loss: 0.3847
# 41/93, training_loss: 0.3725
# 42/93, training_loss: 0.3683
# 43/93, training_loss: 0.3597
# 44/93, training_loss: 0.3259
# 45/93, training_loss: 0.3209
# 46/93, training_loss: 0.3594
# 47/93, training_loss: 0.3415
# 48/93, training_loss: 0.2958
# 49/93, training_loss: 0.3356
# 50/93, training_loss: 0.3375
# 51/93, training_loss: 0.3563
# 52/93, training_loss: 0.3271
# 53/93, training_loss: 0.3236
# 54/93, training_loss: 0.3123
# 55/93, training_loss: 0.2903
# 56/93, training_loss: 0.2994
# 57/93, training_loss: 0.3151
# 58/93, training_loss: 0.3193
# 59/93, training_loss: 0.3028
# 60/93, training_loss: 0.3195
# 61/93, training_loss: 0.3134
# 62/93, training_loss: 0.3159
# 63/93, training_loss: 0.2834
# 64/93, training_loss: 0.2815
# 65/93, training_loss: 0.2661
# 66/93, training_loss: 0.2736
# 67/93, training_loss: 0.2990
# 68/93, training_loss: 0.2737
# 69/93, training_loss: 0.2831
# 70/93, training_loss: 0.2692
# 71/93, training_loss: 0.2522
# 72/93, training_loss: 0.2881
# 73/93, training_loss: 0.2652
# 74/93, training_loss: 0.2581
# 75/93, training_loss: 0.2649
# 76/93, training_loss: 0.2783
# 77/93, training_loss: 0.2560
# 78/93, training_loss: 0.2717
# 79/93, training_loss: 0.2373
# 80/93, training_loss: 0.2425
# 81/93, training_loss: 0.2734
# 82/93, training_loss: 0.2508
# 83/93, training_loss: 0.2277
# 84/93, training_loss: 0.2321
# 85/93, training_loss: 0.2679
# 86/93, training_loss: 0.2567
# 87/93, training_loss: 0.2415
# 88/93, training_loss: 0.2713
# 89/93, training_loss: 0.2258
# 90/93, training_loss: 0.2247
# 91/93, training_loss: 0.2243
# 92/93, training_loss: 0.2406
# 93/93, training_loss: 0.3527
# epoch 2 average loss: 0.3593
# saved new best metric network
# current epoch: 2 current AUC: 0.9988 / current accuracy: 0.9686 best AUC: 0.9988 / at epoch: 2
# ----------
# epoch 3/4
# 1/93, training_loss: 0.2515
# 2/93, training_loss: 0.2224
# 3/93, training_loss: 0.2447
# 4/93, training_loss: 0.2046
# 5/93, training_loss: 0.2262
# 6/93, training_loss: 0.2344
# 7/93, training_loss: 0.2263
# 8/93, training_loss: 0.2237
# 9/93, training_loss: 0.2152
# 10/93, training_loss: 0.2190
# 11/93, training_loss: 0.2097
# 12/93, training_loss: 0.2225
# 13/93, training_loss: 0.1887
# 14/93, training_loss: 0.1819
# 15/93, training_loss: 0.1888
# 16/93, training_loss: 0.1893
# 17/93, training_loss: 0.2155
# 18/93, training_loss: 0.2053
# 19/93, training_loss: 0.1673
# 20/93, training_loss: 0.1905
# 21/93, training_loss: 0.2347
# 22/93, training_loss: 0.1937
# 23/93, training_loss: 0.1820
# 24/93, training_loss: 0.1906
# 25/93, training_loss: 0.1904
# 26/93, training_loss: 0.1702
# 27/93, training_loss: 0.2137
# 28/93, training_loss: 0.1702
# 29/93, training_loss: 0.1735
# 30/93, training_loss: 0.1777
# 31/93, training_loss: 0.1687
# 32/93, training_loss: 0.1782
# 33/93, training_loss: 0.1634
# 34/93, training_loss: 0.1907
# 35/93, training_loss: 0.1546
# 36/93, training_loss: 0.1796
# 37/93, training_loss: 0.1666
# 38/93, training_loss: 0.2242
# 39/93, training_loss: 0.1869
# 40/93, training_loss: 0.1545
# 41/93, training_loss: 0.1714
# 42/93, training_loss: 0.1675
# 43/93, training_loss: 0.1695
# 44/93, training_loss: 0.1471
# 45/93, training_loss: 0.1714
# 46/93, training_loss: 0.1562
# 47/93, training_loss: 0.1474
# 48/93, training_loss: 0.1644
# 49/93, training_loss: 0.1685
# 50/93, training_loss: 0.1583
# 51/93, training_loss: 0.1658
# 52/93, training_loss: 0.1552
# 53/93, training_loss: 0.1643
# 54/93, training_loss: 0.1319
# 55/93, training_loss: 0.1722
# 56/93, training_loss: 0.1501
# 57/93, training_loss: 0.1612
# 58/93, training_loss: 0.1666
# 59/93, training_loss: 0.1544
# 60/93, training_loss: 0.1597
# 61/93, training_loss: 0.1976
# 62/93, training_loss: 0.1638
# 63/93, training_loss: 0.1673
# 64/93, training_loss: 0.1403
# 65/93, training_loss: 0.1554
# 66/93, training_loss: 0.1608
# 67/93, training_loss: 0.1365
# 68/93, training_loss: 0.1541
# 69/93, training_loss: 0.1525
# 70/93, training_loss: 0.1801
# 71/93, training_loss: 0.1263
# 72/93, training_loss: 0.1526
# 73/93, training_loss: 0.1367
# 74/93, training_loss: 0.1580
# 75/93, training_loss: 0.1137
# 76/93, training_loss: 0.1523
# 77/93, training_loss: 0.1254
# 78/93, training_loss: 0.1276
# 79/93, training_loss: 0.1298
# 80/93, training_loss: 0.1435
# 81/93, training_loss: 0.1331
# 82/93, training_loss: 0.1238
# 83/93, training_loss: 0.1400
# 84/93, training_loss: 0.1292
# 85/93, training_loss: 0.1330
# 86/93, training_loss: 0.1211
# 87/93, training_loss: 0.1140
# 88/93, training_loss: 0.1188
# 89/93, training_loss: 0.1133
# 90/93, training_loss: 0.1322
# 91/93, training_loss: 0.1341
# 92/93, training_loss: 0.1379
# 93/93, training_loss: 0.1339
# epoch 3 average loss: 0.1674
# saved new best metric network
# current epoch: 3 current AUC: 0.9995 / current accuracy: 0.9812 best AUC: 0.9995 / at epoch: 3
# ----------
# epoch 4/4
# 1/93, training_loss: 0.1155
# 2/93, training_loss: 0.1401
# 3/93, training_loss: 0.1344
# 4/93, training_loss: 0.1354
# 5/93, training_loss: 0.1211
# 6/93, training_loss: 0.1141
# 7/93, training_loss: 0.1027
# 8/93, training_loss: 0.1273
# 9/93, training_loss: 0.1122
# 10/93, training_loss: 0.1302
# 11/93, training_loss: 0.1270
# 12/93, training_loss: 0.1134
# 13/93, training_loss: 0.1005
# 14/93, training_loss: 0.1150
# 15/93, training_loss: 0.1135
# 16/93, training_loss: 0.1199
# 17/93, training_loss: 0.1109
# 18/93, training_loss: 0.1176
# 19/93, training_loss: 0.1075
# 20/93, training_loss: 0.1131
# 21/93, training_loss: 0.1099
# 22/93, training_loss: 0.1405
# 23/93, training_loss: 0.1171
# 24/93, training_loss: 0.1314
# 25/93, training_loss: 0.1071
# 26/93, training_loss: 0.1339
# 27/93, training_loss: 0.1129
# 28/93, training_loss: 0.1044
# 29/93, training_loss: 0.0926
# 30/93, training_loss: 0.1368
# 31/93, training_loss: 0.1117
# 32/93, training_loss: 0.0883
# 33/93, training_loss: 0.1270
# 34/93, training_loss: 0.1417
# 35/93, training_loss: 0.1123
# 36/93, training_loss: 0.1096
# 37/93, training_loss: 0.1392
# 38/93, training_loss: 0.1145
# 39/93, training_loss: 0.1125
# 40/93, training_loss: 0.0948
# 41/93, training_loss: 0.1291
# 42/93, training_loss: 0.1109
# 43/93, training_loss: 0.1182
# 44/93, training_loss: 0.0989
# 45/93, training_loss: 0.0940
# 46/93, training_loss: 0.1130
# 47/93, training_loss: 0.1120
# 48/93, training_loss: 0.0909
# 49/93, training_loss: 0.1026
# 50/93, training_loss: 0.1119
# 51/93, training_loss: 0.0942
# 52/93, training_loss: 0.1246
# 53/93, training_loss: 0.0978
# 54/93, training_loss: 0.1085
# 55/93, training_loss: 0.1232
# 56/93, training_loss: 0.0943
# 57/93, training_loss: 0.0914
# 58/93, training_loss: 0.0972
# 59/93, training_loss: 0.0843
# 60/93, training_loss: 0.1012
# 61/93, training_loss: 0.0883
# 62/93, training_loss: 0.0976
# 63/93, training_loss: 0.0915
# 64/93, training_loss: 0.0992
# 65/93, training_loss: 0.0979
# 66/93, training_loss: 0.0833
# 67/93, training_loss: 0.0910
# 68/93, training_loss: 0.0995
# 69/93, training_loss: 0.0978
# 70/93, training_loss: 0.0884
# 71/93, training_loss: 0.0846
# 72/93, training_loss: 0.0899
# 73/93, training_loss: 0.0920
# 74/93, training_loss: 0.0886
# 75/93, training_loss: 0.0794
# 76/93, training_loss: 0.0944
# 77/93, training_loss: 0.0994
# 78/93, training_loss: 0.0928
# 79/93, training_loss: 0.0774
# 80/93, training_loss: 0.0959
# 81/93, training_loss: 0.1105
# 82/93, training_loss: 0.0929
# 83/93, training_loss: 0.0849
# 84/93, training_loss: 0.0773
# 85/93, training_loss: 0.0730
# 86/93, training_loss: 0.0963
# 87/93, training_loss: 0.1020
# 88/93, training_loss: 0.0909
# 89/93, training_loss: 0.0963
# 90/93, training_loss: 0.1013
# 91/93, training_loss: 0.0881
# 92/93, training_loss: 0.0740
# 93/93, training_loss: 0.1795
# epoch 4 average loss: 0.1054
# saved new best metric network
# current epoch: 4 current AUC: 0.9998 / current accuracy: 0.9876 best AUC: 0.9998 / at epoch: 4
# train completed, best_metric: 0.9998 at epoch: 4

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val AUC")
x = [(i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %%
rseed = 12345678

train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True).set_random_state(rseed),
        RandFlip(spatial_axis=0, prob=0.5).set_random_state(rseed),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5).set_random_state(rseed),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

# %%
parts = partition_dataset_classes(
    data=np.arange(len(image_files_list)), 
    classes=image_class, 
    ratios=(8, 1, 1), 
    shuffle=True, 
    seed=rseed
)

image_sets = [list(), list(), list()]
label_sets = [list(), list(), list()]

for i, part in enumerate(parts):
    image_sets[i] = [image_files_list[idx] for idx in part]
    label_sets[i] = [image_class[idx] for idx in part]

train_x, val_x, test_x = image_sets
train_y, val_y, test_y = label_sets
print(len(train_x), len(val_x), len(test_x))
# Out:
# 47163 5895 5895
